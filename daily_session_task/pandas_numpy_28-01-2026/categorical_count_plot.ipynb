# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#creating data frame
data = {
    "product_category": [
        "Electronics", "Clothing", "Electronics", "Furniture", "Clothing", "Electronics","Furniture", "Clothing"
    ]
}
data
# Out:
# {'product_category': ['Electronics',
#   'Clothing',
#   'Electronics',
#   'Furniture',
#   'Clothing',
#   'Electronics',
#   'Furniture',
#   'Clothing']}

# %%
df=pd.DataFrame(data)
df
# Out:
#   product_category
# 0      Electronics
# 1         Clothing
# 2      Electronics
# 3        Furniture
# 4         Clothing
# 5      Electronics
# 6        Furniture
# 7         Clothing

# %%
#category count
category_counts = df["product_category"].value_counts()
category_counts
# Out:
# product_category
# Electronics    3
# Clothing       3
# Furniture      2
# Name: count, dtype: int64

# %%
#Product Category Frequency
plt.bar(category_counts.index,category_counts.values)
plt.xlabel("Product Category")
plt.ylabel("Frequency")
plt.title("Product Category Frequency")
plt.show()
