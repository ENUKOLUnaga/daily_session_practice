# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data={
    'month':['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec'],
    'revenue':[20000,15000,21000,23000,26000,25000,26000,27000,29000,28000,21000,29000],
    'expenses':[19000,15000,20000,20000,23000,25000,21000,26000,21000,20000,20000,20000]
}
data
# Out:
# {'month': ['jan',
#   'feb',
#   'mar',
#   'apr',
#   'may',
#   'jun',
#   'jul',
#   'aug',
#   'sep',
#   'oct',
#   'nov',
#   'dec'],
#  'revenue': [20000,
#   15000,
#   21000,
#   23000,
#   26000,
#   25000,
#   26000,
#   27000,
#   29000,
#   28000,
#   21000,
#   29000],
#  'expenses': [19000,
#   15000,
#   20000,
#   20000,
#   23000,
#   25000,
#   21000,
#   26000,
#   21000,
#   20000,
#   20000,
#   20000]}

# %%
#creating dataframe 
df=pd.DataFrame(data)
df
# Out:
#    month  revenue  expenses
# 0    jan    20000     19000
# 1    feb    15000     15000
# 2    mar    21000     20000
# 3    apr    23000     20000
# 4    may    26000     23000
# 5    jun    25000     25000
# 6    jul    26000     21000
# 7    aug    27000     26000
# 8    sep    29000     21000
# 9    oct    28000     20000
# 10   nov    21000     20000
# 11   dec    29000     20000

# %%
#box plot for revenue and expenses
plt.figure(figsize=(10,5))
plt.plot(df["month"], df["revenue"], label="Revenue")
plt.plot(df["month"], df["expenses"], label="Expenses")

plt.xlabel("Month")
plt.ylabel("Amount")
plt.title("Revenue vs Expenses")
plt.legend()
