# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data={
    'hours_studied':[2,3,5,2,4,6],
    'score':[90,80,70,90,60,54]
}
data
# Out:
# {'hours_studied': [2, 3, 5, 2, 4, 6], 'score': [90, 80, 70, 90, 60, 54]}

# %%
#creating dataframe
df=pd.DataFrame(data)
df
# Out:
#    hours_studied  score
# 0              2     90
# 1              3     80
# 2              5     70
# 3              2     90
# 4              4     60
# 5              6     54

# %%
#scaatter plot hour's studied vs score
plt.scatter(df['hours_studied'],df['score'])
plt.show()
